# %%
providers = {
    "GEICO": [4.7, 8.3, 9.2],
    "Progressive": [7.4, 6.7, 8.9],
    "USAA": [3.8, 6.3, 8.1]
}

providers
# Out:
# {'GEICO': [4.7, 8.3, 9.2],
#  'Progressive': [7.4, 6.7, 8.9],
#  'USAA': [3.8, 6.3, 8.1]}

# %% [markdown]
# ### Insurance Provider Recommendation
#
# I would choose Progressive as the insurance provider. Progressive has a minimum rating of 7.4, which is much higher than the minimum ratings for GEICO and USAA. GEICO has the highest average rating, but its minimum rating is only 4.7. This means that some GEICO customers had a much worse experience. Progressive has a lower average rating, but its worst-case rating is much stronger. For me, the lower risk of a very bad customer experience is more important than having the highest average rating. Therefore, I believe Progressive is the safest choice.
